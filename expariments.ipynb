# %%
import sagemaker
from sklearn.model_selection import train_test_split
import boto3
import pandas as pd
# Out:
# d:\MLOPS\Aws-Sagemaker-Project\aws\Lib\site-packages\pydantic\_internal\_fields.py:172: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [11/23/24 20:22:09] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=303693;file://d:\MLOPS\Aws-Sagemaker-Project\aws\Lib\site-packages\botocore\credentials.py\credentials.py]8;;\:]8;id=867218;file://d:\MLOPS\Aws-Sagemaker-Project\aws\Lib\site-packages\botocore\credentials.py#1278\1278]8;;\
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\www58\AppData\Local\sagemaker\sagemaker\config.yaml

# %%
sm_boto3=boto3.client('sagemaker')
sesion=sagemaker.Session()
region=sesion.boto_session.region_name
bucket = 'mobile-buckt-sagemake'
print('Using bucket' + bucket)
# Out:
# Using bucketmobile-buckt-sagemake

# %%
print(region)
# Out:
# us-east-1

# %%
sesion

# %%
import requests
import os
from  zipfile import ZipFile
file_path='https://github.com/arpanchakraborty23/data/raw/refs/heads/main/Job_Placement_Data.zip'
os.makedirs('data', exist_ok=True)
    
response=requests.get(url=file_path)
file_name = 'data/Job_Placement_Data.zip'

with open(file_name, 'wb') as f:
   f.write(response.content)
   
with ZipFile(file_name, 'r') as zip_ref:
   zip_ref.extractall('data')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df=pd.read_csv('D:\MLOPS\Aws-Sagemaker-Project\expariments\data\Job_Placement_Data.csv',index_col=False)

# %%
df.head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# ...

# %%
df.isnull().sum()
# Out:
# gender                 0
# ssc_percentage         0
# ssc_board              0
# hsc_percentage         0
# hsc_board              0
# hsc_subject            0
# degree_percentage      0
# undergrad_degree       0
# work_experience        0
# emp_test_percentage    0
# specialisation         0
# mba_percent            0
# status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               215 non-null    object
#  1   ssc_percentage       215 non-null    float64
#  2   ssc_board            215 non-null    object
#  3   hsc_percentage       215 non-null    float64
#  4   hsc_board            215 non-null    object
#  5   hsc_subject          215 non-null    object
#  6   degree_percentage    215 non-null    float64
#  7   undergrad_degree     215 non-null    object
#  8   work_experience      215 non-null    object
#  9   emp_test_percentage  215 non-null    float64
#  10  specialisation       215 non-null    object
#  11  mba_percent          215 non-null    float64
#  12  status               215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
for col in df.columns:
    if df[col].dtype=='object':
      print(f'No of unique values: {df[col].nunique()}')
      print(f'No of catagories: {df[col].value_counts()}')
      print('*'*40)
# Out:
# No of unique values: 2
# No of catagories: gender
# M    139
# F     76
# Name: count, dtype: int64
# ****************************************
# No of unique values: 2
# No of catagories: ssc_board
# Central    116
# Others      99
# Name: count, dtype: int64
# ****************************************
# No of unique values: 2
# No of catagories: hsc_board
# Others     131
# Central     84
# Name: count, dtype: int64
# ****************************************
# No of unique values: 3
# No of catagories: hsc_subject
# Commerce    113
# Science      91
# Arts         11
# Name: count, dtype: int64
# ****************************************
# No of unique values: 3
# No of catagories: undergrad_degree
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: count, dtype: int64
# ****************************************
# No of unique values: 2
# No of catagories: work_experience
# No     141
# Yes     74
# Name: count, dtype: int64
# ****************************************
# ...

# %%
df.head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df.columns:
    if df[col].dtype=='object':
      df[col]=le.fit_transform(df[col])

# %%
df.head()
# Out:
#    gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  hsc_subject  \
# 0       1           67.00          1           91.00          1            1
# 1       1           79.33          0           78.33          1            2
# 2       1           65.00          0           68.00          0            0
# 3       1           56.00          0           52.00          0            2
# 4       1           85.80          0           73.60          0            1
#
#    degree_percentage  undergrad_degree  work_experience  emp_test_percentage  \
# 0              58.00                 2                0                 55.0
# 1              77.48                 2                1                 86.5
# 2              64.00                 0                0                 75.0
# 3              52.00                 2                0                 66.0
# 4              73.30                 0                0                 96.8
#
#    specialisation  mba_percent  status
# ...

# %%
x=df.drop('status',axis=1)
y=df['status']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.26,random_state=49)

# %%
x_train.shape
# Out:
# (159, 12)

# %% [markdown]
# # saving text and train data

# %%
trainx=pd.DataFrame(x_train)
trainx['label']=y_train
trainx.to_csv('train-v1.csv')

# %%
testx=pd.DataFrame(x_test)
testx['label']=y_test
testx.to_csv('test-v1.csv')

# %%
trainx
# Out:
#      gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  \
# 202       1            70.0          0            63.0          0
# 192       1            65.2          0            61.4          0
# 18        0            63.0          0            66.0          0
# 69        1            73.0          0            73.0          0
# 11        1            69.6          0            68.4          0
# ..      ...             ...        ...             ...        ...
# 114       1            65.0          0            68.0          1
# 182       1            52.0          1            65.0          1
# 168       0            48.0          0            51.0          0
# 173       0            52.0          1            52.0          1
# 170       0            63.4          1            67.2          1
#
#      hsc_subject  degree_percentage  undergrad_degree  work_experience  \
# 202            2               66.0                 2                0
# ...

# %%
bucket
# Out:
# 'mobile-buckt-sagemake'

# %%
# send to data to s3 .sagemaker will take data from s3 bucket
sk_prefix='sagmaker/placemant_clf/sklearncontaner'
train_path=sesion.upload_data(path='train-v1.csv',bucket=bucket,key_prefix=sk_prefix)

test_path=sesion.upload_data(path='test-v1.csv',bucket=bucket,key_prefix=sk_prefix)
print(train_path)
print(test_path)
# Out:
# s3://mobile-buckt-sagemake/sagmaker/placemant_clf/sklearncontaner/train-v1.csv
# s3://mobile-buckt-sagemake/sagmaker/placemant_clf/sklearncontaner/test-v1.csv

# %% [markdown]
# # traning model in aws sagemaker

# %%
# %%writefile aws_sagemaker.py
print("Hello, World!")
from sklearn.ensemble import  RandomForestClassifier
from sklearn.metrics import  accuracy_score,precision_score,classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import sklearn
import joblib
import boto3
import pathlib
from io import  StringIO
import argparse
import os
import numpy as np
import pandas as pd

def model(model_dir):
	clf=joblib.load(os.path.join(model,'model.joblib'))

if __name__=="__main__":
	print('[Info] Extrating argements')
	perser=argparse.ArgumentParser()

	perser.add_argument('--n_estimators',type=int,default=100)
	perser.add_argument('--max_depth',type=int,default=6)

	## data,model, output dir
	perser.add_argument('--model',type=str,default=os.environ.get('SM_MODEL_DIR'))
	perser.add_argument('--train',type=str,default=os.environ.get('SM_CHANNEL_TRAIN'))
	perser.add_argument('--test',type=str,default=os.environ.get('SM_CHANNEL_TEST'))
	perser.add_argument('--train_file',type=str,default=os.environ.get('train-v1.csv'))
	perser.add_argument('--test_file',type=str,default=os.environ.get('test-v1.csv'))

	arg,_=perser.parse_known_args()

	print('sklearn version',sklearn.__version__)
	print('joblib version', joblib.__version__)

	print('readinf data')
	print()
	train_df=pd.read_csv(os.path.join(arg.train,arg.train_file))
	test_df=pd.read_csv(os.path.join(arg.test,arg.test_file))

	x=train_df.drop('status',axis=1)
	y=train_df['status']

	x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.26,random_state=49)	
	
	print('Traning in aws sagemaker .....')
	model=RandomForestClassifier(n_estimators=arg.n_estimators,max_depth=arg.max_depth,verbose=3,n_jobs=-1)

	model.fit(x_train,y_train)

	print('fit data complete')

	model_path=os.path.join(arg.model,'model.joblib')
	joblib.dump(model,model_path)

	print(f' model saved in {model_path}')
	y_test_pred =model.predict(x_test)
	test_model_score = accuracy_score(y_test,y_test_pred)*100
	print('Model Reports .....')
	print(f"Training {model} accuracy {test_model_score}")

	print('precision score',precision_score(y_test,y_test_pred)*100)
	print('clf reports', classification_report(y_test, y_test_pred))
# Out:
# Overwriting aws_sagemaker.py

# %% [markdown]
# ## aws sagemaker endpoint to execute the traing script

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"
sklearn_estimator = SKLearn(
    entry_point='aws_sagemaker.py',
    role='arn:aws:iam::509324781298:role/service-role/AmazonSageMaker-ExecutionRole-20240825T070395',
    instance_count=1,
    instance_type='ml.m5.large',
    framework_version=FRAMEWORK_VERSION,
    base_job_name='RF-Training',
    hyperparameters={
        'n_estimators': 100,
        'max_depth': 6
    },
    use_spot_instances=True, 
    max_wait=9200,
    max_run=7200,  # Ensure max_wait >= max_run
)

# %%
sklearn_estimator.fit({'train':train_path,'test':test_path},wait=True)
# Out:
# [11/23/24 20:34:56] INFO     Creating training-job with name: RF-Training-2024-11-23-15-04-40-447   ]8;id=512415;file://d:\MLOPS\Aws-Sagemaker-Project\aws\Lib\site-packages\sagemaker\session.py\session.py]8;;\:]8;id=903364;file://d:\MLOPS\Aws-Sagemaker-Project\aws\Lib\site-packages\sagemaker\session.py#1042\1042]8;;\
# 2024-11-23 15:05:01 Starting - Starting the training job...
# 2024-11-23 15:05:40 Downloading - Downloading input data...
# 2024-11-23 15:06:05 Downloading - Downloading the training image..2024-11-23 15:06:50,243 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-11-23 15:06:50,246 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-11-23 15:06:50,280 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-11-23 15:06:50,432 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# ...

# %%
sklearn_estimator.latest_training_job.wait(logs='None')
artifacts=sm_boto3.describe_training_job(
    TraningJobName=sklearn_estimator.latest_training_job.name
)['ModelArtifacts']['S3ModelArtifacts']
# Out:
# Exception ignored in: <finalize object at 0x1c4901f3b60; dead>
# Traceback (most recent call last):
#   File "d:\MLOPS\Aws-Sagemaker-Project\aws\Lib\weakref.py", line 588, in __call__
#     info = self._registry.pop(self, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 sklearn_estimator.latest_training_job.wait(logs='None')                                      │
# │   2 artifacts=sm_boto3.describe_training_job(                                                    │
# │   3 │   TraningJobName=sklearn_estimator.latest_training_job.name                                │
# ...

# %% [markdown]
# # Deployment

# %%
from sagemaker.sklearn.model import SKLearnModel
from time import gmtime,strftime

model_name='RF-model'+ strftime('%H_%M_%S',gmtime())
model=SKLearnModel(
   name=model_name,
   model_data=artifacts,
   role='sagemaker-us-east-1-509324781298',
   entry_point='aws_sagemaker.py',
   framework_version=FRAMEWORK_VERSION
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │    4 model_name='RF-model'+ strftime('%H_%M_%S',gmtime())                                        │
# │    5 model=SKLearnModel(                                                                         │
# │    6    name=model_name,                                                                         │
# │ ❱  7    model_data=artifacts,                                                                    │
# │    8    role='sagemaker-us-east-1-509324781298',                                                 │
# │    9    entry_point='aws_sagemaker.py',                                                          │
# ...

# %%
model

# %%
# endpoint deployment
end_point='RF-model'+ strftime('%H_%M_%S',gmtime())
print('Endpoint={}'.format(end_point))
predictor=model.deploy(
    initial_instance_count=1,
    instance_type='ml.m4.xlarge',
    endpoint_name=end_point
)
# Out:
# Endpoint=RF-model15_26_53
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:4                                                                                    │
# │                                                                                                  │
# │   1 # endpoint deployment                                                                        │
# │   2 end_point='RF-model'+ strftime('%H_%M_%S',gmtime())                                          │
# │   3 print('Endpoint={}'.format(end_point))                                                       │
# │ ❱ 4 predictor=model.deploy(                                                                      │
# │   5 │   initial_instance_count=1,                                                                │
# │   6 │   instance_type='ml.m4.xlarge',                                                            │
# ...
